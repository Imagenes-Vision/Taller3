# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.segmentation import flood

# %%
amour = cv2.imread('images/AMOUR_AVEC_RAMPE.png')
plt.imshow(amour, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 254.5, 254.5, -0.5)

# %%
amour = cv2.imread('images/AMOUR_AVEC_RAMPE.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(amour, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 254.5, 254.5, -0.5)

# %%
thres_value_ot, thres_image_ot = cv2.threshold(amour, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.imshow(thres_image_ot, cmap='gray', vmin=0, vmax=255)

# %%
from skimage.filters import threshold_local

ti = threshold_local(amour, block_size=251, method='mean', offset=10)
binary_image = amour > ti
thresholded_image = (binary_image*255).astype('uint8')

plt.imshow(thresholded_image, cmap='gray', vmin=0, vmax=255)

# %%
#Selección de la semilla
semilla_izq = (100, 150)  # Adjust based on your image

# Definición de la variación de intensidad permitida
tolerancia= 90

# Apply region growing using flood
mascara_izq = flood(thresholded_image, semilla_izq, tolerance=tolerancia)


plt.imshow(mascara_izq, cmap='gray')
plt.axis("off")
# Out:
# (-0.5, 254.5, 254.5, -0.5)
